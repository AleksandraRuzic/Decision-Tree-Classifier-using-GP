# %%
import Tree
import random
import copy

# %%
population_size = 10
tournament_size = 5
num_of_iterations = 10

# %%
def init_individual():
    left_part = random.sample(Tree.column_names, 1)[0]
    if left_part in Tree.atributes['num']:
        relation = random.sample(Tree.relations['num'], 1)[0]
        if Tree.data[left_part].dtype == 'float64':
            right_part = random.uniform(min(Tree.data[left_part]), max(Tree.data[left_part]))
        elif Tree.data[left_part].dtype == 'int64':
            right_part = random.randrange(min(Tree.data[left_part]), max(Tree.data[left_part]))
    elif left_part in Tree.atributes['cat']:
        relation = random.sample(Tree.relations['cat'], 1)[0]
        right_part = random.sample(set(data[left_part]), 1)[0]
    t = Tree.Tree([left_part, relation, right_part])
    t.add_node(t.root_node, True, random.sample(Tree.class_names, 1))
    t.add_node(t.root_node, False, random.sample(Tree.class_names, 1)) 
    return t

# %%
def selection(population):
    max_fitness = 0.0
    k = -1
    for i in range(tournament_size):
        j = random.randrange(population_size)
        if population[j].calculate_fitness() > max_fitness:
            max_fitness = population[j].calculate_fitness()
            k = j
    return k

# %%
def build_block(tree):
    viable_indexes = set(
        filter(lambda index:  
            not any(index2 == 2*index for index2 in tree.setOfIndexes),
            tree.setOfIndexes))
    tree_index = random.sample(viable_indexes, 1)[0]
    new_node = init_individual().root_node
    tree.remove_node(tree_index)
    tree.add_subtree(tree_index, new_node)

# %%
def crossover(parent1, parent2):
    child1 = copy.deepcopy(parent1)
    child2 = copy.deepcopy(parent2)

    child1_viable_indexes = set(
        filter(lambda index:  
            any(index2 == 2*index for index2 in child1.setOfIndexes),
            child1.setOfIndexes))
    child2_viable_indexes = set(
        filter(lambda index: 
            any(index2 == 2*index for index2 in child2.setOfIndexes),
            child2.setOfIndexes))
    child1_index = random.sample(child1_viable_indexes, 1)[0]
    child2_index = random.sample(child2_viable_indexes, 1)[0]
    
    if child1_index == 1 or child2_index == 1:
        return [child1, child2]

    child1_subtree = child1.index_of(child1_index)
    child2_subtree = child2.index_of(child2_index)
    
    child1.remove_node(child1_index)
    child2.remove_node(child2_index)
    
    child1.add_subtree(child1_index, child2_subtree)
    child2.add_subtree(child2_index, child1_subtree)
    
    return [child1, child2]

# %%
def relation_mutation(tree):
    
    tree_viable_indexes = set(
        filter(lambda index:  
            any(index2 == 2*index for index2 in tree.setOfIndexes),
            tree.setOfIndexes))
    tree_index = random.sample(tree_viable_indexes, 1)[0]
    node = tree.index_of(tree_index)
    if node.left_part in Tree.atributes['num']:
        node.relation = random.sample(Tree.relations['num'], 1)[0]
    elif node.left_part in Tree.atributes['cat']:
        node.relation = random.sample(Tree.relations['cat'], 1)[0]

# %%
def right_side_mutation(tree):
    
    tree_viable_indexes = set(
        filter(lambda index:  
            any(index2 == 2*index for index2 in tree.setOfIndexes),
            tree.setOfIndexes))
    tree_index = random.sample(tree_viable_indexes, 1)[0]
    node = tree.index_of(tree_index)
    if node.left_part in Tree.atributes['num']:
        if Tree.data[node.left_part].dtype == 'float64':
            node.right_part = random.uniform(
                min(Tree.data[node.left_part]), max(Tree.data[node.left_part]))
        elif Tree.data[node.left_part].dtype == 'int64':
            node.right_part = random.randrange(
                min(Tree.data[node.left_part]), max(Tree.data[node.left_part]))
    elif node.left_part in Tree.atributes['cat']:
        node.right_part = random.sample(set(data[node.left_part]), 1)[0]

# %%
#todo: set probability for operators

population = []
newPopulation = []
for i in range(population_size):
    population.append(init_individual())
    newPopulation.append(init_individual())
    
for iteration in range(num_of_iterations):
    for i in range(0, population_size, 2):
        k1 = selection(population)
        k2 = selection(population)
        [child1, child2] = crossover(population[k1], population[k2])
        relation_mutation(child1)
        relation_mutation(child2)
        right_side_mutation(child1)
        right_side_mutation(child2)
        build_block(child1)
        build_block(child2)
        newPopulation[i] = child1
        newPopulation[i+1] = child2
    maximum = 0
    tree = None
    for i in range(population_size):
        if newPopulation[i].calculate_fitness() > maximum:
            maximum = newPopulation[i].calculate_fitness()
            tree = copy.deepcopy(newPopulation[i])
    print()
    tree.print_tree()
    print(tree.calculate_fitness())
    print()
    population = newPopulation
# Out:
# 1 Petal_Length   <=   1.8458820951271613
# 2 setosa
# 3 Sepal_Length   >=   5.327239937430289
# 6 versicolor
# 7 versicolor
# 0.6533333333333333
#
#
# 1 Sepal_Width   >   2.9804087169750058
# 2 Sepal_Length   <   6.0927138301381625
# 4 Sepal_Length   >   7.0251851573700765
# 8 virginica
# 9 Sepal_Width   >   2.751622895380949
# 18 setosa
# 19 virginica
# 5 versicolor
# 3 versicolor
# 0.6066666666666667
#
#
# 1 Sepal_Width   >=   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >   7.0251851573700765
# 8 Sepal_Length   >   7.0251851573700765
# 16 virginica
# 17 Sepal_Width   >   2.751622895380949
# 34 setosa
# 35 virginica
# 9 Sepal_Width   >   2.751622895380949
# 18 setosa
# 19 virginica
# 5 Petal_Length   <=   3.9287379243137344
# 10 setosa
# 11 virginica
# 3 versicolor
# 0.74
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >   7.0251851573700765
# 8 Sepal_Length   >   7.0251851573700765
# 16 virginica
# 17 Sepal_Width   >   4.35737414570344
# 34 setosa
# 35 virginica
# 9 Sepal_Width   >   2.751622895380949
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   >   6.257283098028056
# 72 versicolor
# 73 setosa
# 37 setosa
# 19 virginica
# 5 Petal_Length   <=   1.716478955091311
# 10 setosa
# 11 virginica
# 3 versicolor
# 0.7333333333333333
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >=   7.0251851573700765
# 8 Sepal_Length   >   7.0251851573700765
# 16 virginica
# 17 Sepal_Width   >   4.35737414570344
# 34 Sepal_Width   <=   3.3548023681737265
# 68 virginica
# 69 Sepal_Length   >   4.998083701222127
# 138 virginica
# 139 virginica
# 35 virginica
# 9 Sepal_Width   >   2.449424415785754
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   >   6.257283098028056
# 72 versicolor
# 73 setosa
# 37 setosa
# 19 virginica
# 5 Petal_Length   <=   3.263327165549417
# 10 setosa
# 11 virginica
# 3 versicolor
# 0.74
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >=   7.0251851573700765
# 8 Sepal_Length   >   7.0251851573700765
# 16 virginica
# 17 Sepal_Width   >   4.35737414570344
# 34 Petal_Length   <=   1.1939331319124644
# 68 Sepal_Length   >   4.3561365455010685
# 136 virginica
# 137 Sepal_Width   >   2.751622895380949
# 274 setosa
# 275 virginica
# 69 setosa
# 35 virginica
# 9 Sepal_Width   >   2.449424415785754
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   >   6.257283098028056
# 72 versicolor
# 73 setosa
# 37 setosa
# 19 Petal_Length   <=   4.384175313542842
# 38 setosa
# 39 virginica
# 5 Petal_Length   <=   3.263327165549417
# 10 setosa
# 11 virginica
# 3 versicolor
# 0.74
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >=   7.0251851573700765
# 8 Sepal_Length   >   7.0251851573700765
# 16 Petal_Length   <=   4.36508846136229
# 32 setosa
# 33 virginica
# 17 Sepal_Width   >   3.2831612118141402
# 34 Petal_Length   <=   1.1939331319124644
# 68 Sepal_Length   <=   4.3561365455010685
# 136 virginica
# 137 Sepal_Width   >   2.751622895380949
# 274 setosa
# 275 virginica
# 69 setosa
# 35 virginica
# 9 Sepal_Width   >   2.449424415785754
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   >   6.257283098028056
# 72 versicolor
# 73 setosa
# 37 setosa
# 19 Petal_Length   <=   4.384175313542842
# 38 setosa
# 39 virginica
# 5 Petal_Length   <=   3.263327165549417
# 10 setosa
# 11 virginica
# 3 versicolor
# 0.74
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >=   7.0251851573700765
# 8 Sepal_Length   >   7.0251851573700765
# 16 virginica
# 17 Sepal_Width   >   4.35737414570344
# 34 Petal_Length   >   1.1939331319124644
# 68 Sepal_Length   >   6.257283098028056
# 136 versicolor
# 137 Petal_Width   >=   1.3298229077086645
# 274 setosa
# 275 virginica
# 69 setosa
# 35 virginica
# 9 Sepal_Width   >   3.7765402387054845
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   >   6.257283098028056
# 72 versicolor
# 73 Petal_Width   >=   1.3298229077086645
# 146 setosa
# 147 virginica
# 37 setosa
# 19 Petal_Length   <=   4.322639805954934
# 38 Petal_Length   >=   3.817018929979278
# 76 virginica
# 77 setosa
# 39 virginica
# 5 Petal_Length   <=   3.263327165549417
# 10 setosa
# 11 virginica
# 3 Petal_Length   >   4.083588058529836
# 6 virginica
# 7 versicolor
# 0.76
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >=   5.552725002046062
# 8 Petal_Length   >   4.36508846136229
# 16 setosa
# 17 virginica
# 9 Sepal_Width   >   3.7765402387054845
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   <=   6.257283098028056
# 72 versicolor
# 73 Petal_Width   >=   1.3298229077086645
# 146 setosa
# 147 Petal_Length   <=   1.507891011453217
# 294 setosa
# 295 virginica
# 37 setosa
# 19 Petal_Length   <=   3.395460241560359
# 38 Petal_Length   >=   3.817018929979278
# 76 virginica
# 77 setosa
# 39 virginica
# 5 Petal_Length   <=   3.263327165549417
# 10 setosa
# 11 Petal_Width   <=   1.1943983856986227
# 22 versicolor
# 23 virginica
# 3 versicolor
# 0.74
#
#
# 1 Sepal_Width   >   2.9663122650010925
# 2 Sepal_Length   <=   5.0607948933280795
# 4 Sepal_Length   >=   5.552725002046062
# 8 Petal_Length   >   4.36508846136229
# 16 Sepal_Length   <   7.482993088219515
# 32 virginica
# 33 setosa
# 17 virginica
# 9 Sepal_Width   >   3.7765402387054845
# 18 Petal_Length   <=   1.1939331319124644
# 36 Sepal_Length   <=   6.257283098028056
# 72 versicolor
# 73 Sepal_Length   <=   5.0607948933280795
# 146 Sepal_Length   >=   5.552725002046062
# 292 Petal_Length   >   4.36508846136229
# 584 Sepal_Length   <   5.050854495759422
# 1168 virginica
# 1169 setosa
# 585 virginica
# 293 Sepal_Width   >   3.649079010833298
# 586 Petal_Length   <   1.1939331319124644
# 1172 Sepal_Length   <=   6.257283098028056
# 2344 Sepal_Length   <   4.761052672195157
# 4688 virginica
# 4689 virginica
# 2345 Petal_Width   >=   1.3298229077086645
# 4690 Petal_Width   <   0.4894086377382394
# 9380 virginica
# 9381 virginica
# 4691 Petal_Length   <=   3.263327165549417
# 9382 setosa
# 9383 virginica
# 1173 setosa
# 587 Petal_Length   <=   3.395460241560359
# 1174 Petal_Length   >=   3.817018929979278
# 2348 virginica
# 2349 setosa
# 1175 virginica
# 147 Petal_Length   <=   3.263327165549417
# 294 setosa
# 295 Petal_Width   <=   0.20460082660491646
# 590 versicolor
# 591 virginica
# 37 setosa
# 19 Petal_Length   <=   3.395460241560359
# 38 Petal_Length   >=   3.817018929979278
# 76 virginica
# 77 setosa
# 39 virginica
# 5 Petal_Length   <=   3.263327165549417
# 10 setosa
# 11 Petal_Width   <=   0.20460082660491646
# 22 versicolor
# 23 virginica
# 3 versicolor
# 0.74
